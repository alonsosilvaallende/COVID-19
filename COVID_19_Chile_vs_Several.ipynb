# %% [markdown]
# <a href="https://colab.research.google.com/github/alonsosilvaallende/COVID-19/blob/master/COVID_19_Chile_vs_Several.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn')

# %%
known_cases = pd.read_csv("https://covid.ourworldindata.org/data/ecdc/total_cases.csv",\
                          index_col='date')
known_cases = known_cases.fillna(method='pad')
known_cases = known_cases.fillna(0)

# %%
deaths = pd.read_csv("https://covid.ourworldindata.org/data/ecdc/total_deaths.csv", index_col='date')
deaths = deaths.fillna(0)

# %%
# countries_list = ['China', 'South Korea', 'Italy', 'Spain', 'France', 'Japan', 'United States', 'Chile']
countries_list = ['China', 'South Korea', 'Italy', 'Spain', 'France', 'United States', 'Chile']

# %%
# Population in millions from Wikipedia

# population = [1427, 51, 60, 46, 67, 126, 328, 19]
population = [1427, 51, 60, 46, 67, 328, 19]

# %%
known_cases['China'].tail(3)
# Out:
# date
# 2020-03-26    81968
# 2020-03-27    82079
# 2020-03-28    82213
# Name: China, dtype: int64

# %%
known_cases['Chile'].tail(3)
# Out:
# date
# 2020-03-26    1142.0
# 2020-03-27    1306.0
# 2020-03-28    1610.0
# Name: Chile, dtype: float64

# %%
(known_cases['China']/1427).tail(3)
# Out:
# date
# 2020-03-26    57.440785
# 2020-03-27    57.518570
# 2020-03-28    57.612474
# Name: China, dtype: float64

# %%
(known_cases['Chile']/18).tail(3)
# Out:
# date
# 2020-03-26    63.444444
# 2020-03-27    72.555556
# 2020-03-28    89.444444
# Name: Chile, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,7))

for i, country in enumerate(countries_list):
  plt.plot(known_cases[country]/population[i], label=country, linewidth=2, marker='o')

ax.set_title('COVID-19: Número de casos confirmados por millón de habitantes', fontsize='x-large')
ax.set_xlabel('fecha (año-mes-día)', fontsize='x-large')
ax.set_ylabel('número de casos confirmados por millón de habitantes', fontsize='x-large')
ax.set_xticks(np.arange(0, len(known_cases['Italy']),5))
plt.xticks(rotation=90)
plt.legend(fontsize='x-large')
plt.yscale("log")
plt.show()

# %%
known_cases['United States'].tail(3)
# Out:
# date
# 2020-03-26     69194
# 2020-03-27     85991
# 2020-03-28    104686
# Name: United States, dtype: int64

# %%
known_cases['Italy'].tail(3)
# Out:
# date
# 2020-03-26    74386
# 2020-03-27    80539
# 2020-03-28    86498
# Name: Italy, dtype: int64

# %%
known_cases['China'].tail(3)
# Out:
# date
# 2020-03-26    81968
# 2020-03-27    82079
# 2020-03-28    82213
# Name: China, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,7))

for i, country in enumerate(countries_list):
  plt.plot(known_cases[country], label=country, linewidth=2, marker='o')

# ax.set_title('COVID-19: Número de casos confirmados', fontsize='x-large')
# ax.set_xlabel('fecha (año-mes-día)', fontsize='x-large')
# ax.set_ylabel('número de casos confirmados', fontsize='x-large')
ax.set_title('COVID-19: Number of confirmed cases', fontsize='x-large')
ax.set_xlabel('date (year-month-day)', fontsize='x-large')
ax.set_ylabel('number of confirmed cases', fontsize='x-large')
ax.set_xticks(np.arange(0, len(known_cases['Italy']),5))
plt.xticks(rotation=90)
plt.legend(fontsize='x-large')
plt.yscale("log")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))

for i, country in enumerate(countries_list):
  plt.plot(deaths[country]/population[i], label=country, linewidth=2, marker='o')

ax.set_title('COVID-19: Número de muertes por millón de habitantes', fontsize='x-large')
ax.set_xlabel('fecha (año-mes-día)', fontsize='x-large')
ax.set_ylabel('número de muertes por millón de habitantes', fontsize='x-large')
ax.set_xticks(np.arange(0, len(deaths['Italy']),5))
plt.xticks(rotation=90)
plt.legend(fontsize='x-large')
plt.yscale("log")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))

for i, country in enumerate(countries_list):
  plt.plot(deaths[country], label=country, linewidth=2, marker='o')

ax.set_title('COVID-19: Número de muertes', fontsize='x-large')
ax.set_xlabel('fecha (año-mes-día)', fontsize='x-large')
ax.set_ylabel('número de muertes', fontsize='x-large')
ax.set_xticks(np.arange(0, len(deaths['Italy']),5))
plt.xticks(rotation=90)
plt.legend(fontsize='x-large')
plt.yscale("log")
plt.show()
